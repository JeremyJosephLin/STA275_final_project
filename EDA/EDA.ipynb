# %% [markdown]
# # Exploratory Data Analysis
#
# We want to look at the relationship between Cognitive Function (Fine, MCI, AD) and the underlying Pathology (AD vs no AD).
#
# ## Loading the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from importlib import reload
import seaborn as sns
from tabulate import tabulate
import sidetable as stb
import os, sys

#sys.path.append(os.path.join("../data_cleaned/", "utils"))
import load_data

# %%
uds = pd.read_csv("../data/data_cleaned/uds.csv")
mri = pd.read_csv("../data/data_cleaned/mri.csv")
csf = pd.read_csv("../data/data_cleaned/csf.csv")


print(uds.shape, mri.shape, csf.shape)
# Out:
# (45100, 96) (2873, 173) (2180, 7)

# %%
csf
# Out:
#       NACCADC      NACCID  CSFABETA  CSFPTAU  CSFTTAU  CSFABMD  CSFPTMD  \
# 0        2289  NACC265439    491.00      NaN   388.00        1      NaN
# 1        2289  NACC557124    614.40    38.60    32.20        2      2.0
# 2        2289  NACC413711    365.00      NaN   793.00        1      NaN
# 3        2289  NACC769575    274.00      NaN   255.00        1      NaN
# 4        2289  NACC773787    348.40    84.10    49.90        2      2.0
# ...       ...         ...       ...      ...      ...      ...      ...
# 3012     2793  NACC023040    476.13   121.90   449.53        2      2.0
# 3013     2793  NACC074386    610.83    59.58   304.56        2      2.0
# 3014     2793  NACC216377    886.73   284.08  1317.00        2      2.0
# 3015     2793  NACC538380    427.43   116.80   457.12        2      2.0
# 3016     2793  NACC437998    658.70    79.95   272.73        2      2.0
#
#       CSFTTMD
# 0         1.0
# 1         2.0
# 2         1.0
# 3         1.0
# 4         2.0
# ...       ...
# 3012      2.0
# 3013      2.0
# 3014      2.0
# 3015      2.0
# 3016      2.0
#
# [3017 rows x 8 columns]

# %% [markdown]
# #### recoding the UDSD/ ALZP so that they agree with how we will classify and also getting rid of 1 category of UDSD

# %%
uds['UDSD_3'] = uds['NACCUDSD'].map({1: 'Normal cognition', 3: 'MCI', 4: 'Dementia'})

uds['ALZP_3'] = uds['NACCALZP'].map({ 1: 'AD contribution', 2: 'AD contribution',  3: 'No AD contribution' , 7: 'No AD contribution' ,
                                        8: 'Normal cognition'})

# %%
uds
# Out:
#            NACCID  NACCADC  NACCAGE  NACCVNUM  EDUC  SEX  NACCAPOE  NACCUDSD  \
# 0      NACC020208      186       69         1  16.0    1       NaN         3
# 1      NACC107305      186       74         1  18.0    2       NaN         1
# 2      NACC151065      186       86         1  14.0    2       NaN         3
# 3      NACC187327      186       68         1  14.0    2       NaN         1
# 4      NACC188799      186       78         1  14.0    2       NaN         3
# ...           ...      ...      ...       ...   ...  ...       ...       ...
# 45095  NACC993286     9661       75         1  21.0    1       1.0         2
# 45096  NACC994463     9661       66         1  16.0    1       2.0         4
# 45097  NACC995870     9661       53         1  16.0    2       1.0         1
# 45098  NACC998475     9661       70         1  13.0    2       1.0         3
# 45099  NACC999391     9661       87         1  13.0    1       1.0         3
#
#        NACCALZP  MEMORY  ...  CRAFTDRE  DIGFORCT  DIGFORSL  DIGBACCT  \
# 0             1     1.0  ...       1.0       8.0       6.0       7.0
# 1             8     0.0  ...      15.0       7.0       6.0       6.0
# 2             7     0.0  ...      16.0       3.0       4.0       2.0
# 3             8     0.5  ...      17.0      10.0       7.0       9.0
# 4             7     0.5  ...       0.0       7.0       6.0       7.0
# ...         ...     ...  ...       ...       ...       ...       ...
# 45095         7     0.0  ...       NaN       NaN       NaN       NaN
# 45096         1     1.0  ...       NaN       NaN       NaN       NaN
# 45097         8     0.0  ...      16.0      11.0       9.0      11.0
# 45098         7     0.0  ...       NaN       NaN       NaN       NaN
# 45099         7     0.5  ...       NaN       NaN       NaN       NaN
#
#        DIGBACLS    datetime      NACCAD3      NACCAD5            UDSD_3  \
# 0           5.0  2020-06-09       MCI-AD       MCI-AD               MCI
# 1           5.0  2021-12-01      Healthy      Healthy  Normal cognition
# 2           2.0  2021-12-21          NaN    MCI-NonAD               MCI
# 3           6.0  2021-09-14      Healthy      Healthy  Normal cognition
# 4           5.0  2022-02-07          NaN    MCI-NonAD               MCI
# ...         ...         ...          ...          ...               ...
# 45095       NaN  2006-08-04          NaN          NaN               NaN
# 45096       NaN  2012-01-27  Dementia-AD  Dementia-AD          Dementia
# 45097       7.0  2019-11-21      Healthy      Healthy  Normal cognition
# 45098       NaN  2006-10-20          NaN    MCI-NonAD               MCI
# 45099       NaN  2006-03-02          NaN    MCI-NonAD               MCI
#
#                    ALZP_3
# 0         AD contribution
# 1        Normal cognition
# 2      No AD contribution
# 3        Normal cognition
# 4      No AD contribution
# ...                   ...
# 45095  No AD contribution
# 45096     AD contribution
# 45097    Normal cognition
# 45098  No AD contribution
# 45099  No AD contribution
#
# [45100 rows x 98 columns]

# %% [markdown]
# #### Recode data so that we can easily see proportion of men vs women

# %%
def binary_sex(series):
    if series  == 1:
        return 0
    elif series == 2:
        return 1

uds['SEX_BIN'] = uds['SEX'].apply(binary_sex)
uds['SEX_BIN'].value_counts(sort=False)
# Out:
# 0    19349
# 1    25751
# Name: SEX_BIN, dtype: int64

# %%
uds['SEX'].value_counts(sort=False)
# Out:
# 1    19349
# 2    25751
# Name: SEX, dtype: int64

# %% [markdown]
# ## EDA
#
# UDSD:
# 1 = Normal cognition
# 2 = Impaired-not-MCI
# 3 = MCI
# 4 = Dementia
#
#
# ALZP:
# 1 = Primary
# 2 = Contributing
# 3 = Non-contributing
# 7 = Cognitively impaired but not AD diagnosis
# 8 = Diagnosis of normal cognition
#
# First look at demographics of cognitive impairment and responsible pathology

# %%
uds['NACCUDSD'] = pd.Categorical(uds.NACCUDSD)
uds['NACCALZP'] = pd.Categorical(uds.NACCALZP)
uds['UDSD_LAB'] = uds['NACCUDSD'].map({1: 'Normal cognition', 2: 'Impaired-not-MCI', 3: 'MCI', 4: 'Dementia'})

uds['ALZP_LAB'] = uds['NACCALZP'].map({ 1: 'Primary', 2: 'Contributing', 3: 'Non-contributing' ,
                                       7: 'Cognitively impaired - not AD', 8: 'Diagnosis of normal cognition'})

# %%
pd.crosstab( uds.NACCALZP, uds.NACCUDSD, 
            #rownames=['Primary', 'Contributing', 'Non-Cont', 'Not AD', 'Normal Cog','Total'], 
            #colnames=['Normal', 'Impaired not MCI', 'MCI', 'Dementia','Total'],
            margins=True)
# Out:
# NACCUDSD      1     2     3      4    All
# NACCALZP
# 1             0   332  4255  11288  15875
# 2             0    40   236    714    990
# 3             0     0     4      5      9
# 7             0  1621  5357   3476  10454
# 8         17772     0     0      0  17772
# All       17772  1993  9852  15483  45100

# %%
pd.crosstab( uds.NACCALZP, uds.NACCUDSD, 
            #rownames=['Primary', 'Contributing', 'Non-Cont', 'Not AD', 'Normal Cog','Total'], 
            #colnames=['Normal', 'Impaired not MCI', 'MCI', 'Dementia','Total'],
            values = uds['NACCAGE'],
            aggfunc = 'mean',
            margins=True).round(2)
# Out:
# NACCUDSD      1      2      3      4    All
# NACCALZP
# 1           NaN  73.35  73.41  74.21  73.98
# 2           NaN  72.58  73.38  71.93  72.30
# 3           NaN    NaN  69.00  73.60  71.56
# 7           NaN  69.37  72.11  67.13  70.03
# 8         70.14    NaN    NaN    NaN  70.14
# All       70.14  70.09  72.70  72.52  71.51

# %%
pd.crosstab( uds.NACCALZP, uds.NACCUDSD, 
            #rownames=['Primary', 'Contributing', 'Non-Cont', 'Not AD', 'Normal Cog','Total'], 
            #colnames=['Normal', 'Impaired not MCI', 'MCI', 'Dementia','Total'],
            values = uds['EDUC'],
            aggfunc = 'mean',
            margins=True).round(2)
# Out:
# NACCUDSD      1      2      3      4    All
# NACCALZP
# 1           NaN  16.07  15.60  14.18  14.60
# 2           NaN  14.65  14.96  14.61  14.70
# 3           NaN    NaN  16.50  17.50  17.00
# 7           NaN  14.48  14.91  15.06  14.89
# 8         15.79    NaN    NaN    NaN  15.79
# All       15.79  14.75  15.21  14.39  15.14

# %%
pd.crosstab( uds.NACCALZP, uds.NACCUDSD, 
            #rownames=['Primary', 'Contributing', 'Non-Cont', 'Not AD', 'Normal Cog','Total'], 
            #colnames=['Normal', 'Impaired not MCI', 'MCI', 'Dementia','Total'],
            values = uds['SEX_BIN'],
            aggfunc = 'mean',
            margins=True).round(2)
# Out:
# NACCUDSD     1     2     3     4   All
# NACCALZP
# 1          NaN  0.55  0.50  0.56  0.55
# 2          NaN  0.48  0.51  0.44  0.46
# 3          NaN   NaN  0.50  0.20  0.33
# 7          NaN  0.58  0.50  0.40  0.48
# 8         0.65   NaN   NaN   NaN  0.65
# All       0.65  0.58  0.50  0.52  0.57

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(
    pd.crosstab( uds.ALZP_3, uds.UDSD_3, 
            colnames=['Cognition'], 
            rownames=['Pathology']),
    annot = True,
    cmap="Purples",
    fmt='d'
)
plt.title("Raw Count, Pathology vs Cognition")
plt.savefig("count_by_UDSD_ALZP", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(
    pd.crosstab( uds.ALZP_3, uds.UDSD_3, 
            colnames=['Cognition'], 
            rownames=['Pathology'],
            values = uds['NACCAGE'],
            aggfunc = 'mean',
            margins=False,
            margins_name="Total").round(2), 
    annot = True,
    cmap="Purples"
)
plt.title("Mean Age by Pathology and Cognition")
plt.savefig("age_by_UDSD_ALZP", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(
    pd.crosstab( uds.ALZP_3, uds.UDSD_3, 
            colnames=['Cognition'], 
            rownames=['Pathology'],
            values = uds['EDUC'],
            aggfunc = 'mean',
            margins=False,
            margins_name="Total").round(2), 
    cmap="Purples",
    annot = True
)
plt.title("Mean Years of Education by Pathology and Cognition")
plt.savefig("educ_by_UDSD_ALZP", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(
    pd.crosstab( uds.ALZP_3, uds.UDSD_3, 
            colnames=['Cognition'], 
            rownames=['Pathology'],
            values = uds['SEX_BIN'],
            aggfunc = 'mean',
            margins=False,
            margins_name="Total").round(2), 
    annot = True,
    cmap="Purples"
)
plt.title("Percentage Female by Pathology and Cognition")
plt.savefig("female_by_UDSD_ALZP", bbox_inches='tight')
plt.show()

# %%
mri.groupby('NACCID')['MRIMO'].count()
# Out:
# NACCID
# NACC000034    1
# NACC000225    2
# NACC000511    1
# NACC000531    2
# NACC000540    1
#              ..
# NACC999546    2
# NACC999566    2
# NACC999724    1
# NACC999780    1
# NACC999854    3
# Name: MRIMO, Length: 7328, dtype: int64

# %%
# Creating histogram
fig, axs = plt.subplots(figsize =(10, 7))
 
axs.hist(mri.groupby('NACCID')['MRIMO'].count())

plt.title('Number of Observations per Person in MRI dataset')
plt.xlabel('Number of Visits')
plt.ylabel('Frequency')
plt.savefig('mri_obs_per_person.png')
# Show plot
plt.show()

# %%
# Creating histogram
fig, axs = plt.subplots(figsize =(10, 7))
 
axs.hist(csf.groupby('NACCID')['NACCADC'].count())
plt.title('Number of Observations per Person in CSF dataset') 
plt.xlabel('Number of Visits')
plt.ylabel('Frequency')
plt.savefig('csf_obs_per_person.png')
# Show plot
plt.show()

# %% [markdown]
# ## Relationship within missing values

# %%
pd.options.display.max_rows = 999 
uds.stb.missing()
# Out:
#           missing  total    percent
# ELATSEV     43620  45100  96.718404
# HALLSEV     43170  45100  95.720621
# DELSEV      41895  45100  92.893570
# MOTSEV      40294  45100  89.343681
# DISNSEV     39664  45100  87.946785
# APPSEV      37750  45100  83.702882
# AGITSEV     36709  45100  81.394678
# NITESEV     35806  45100  79.392461
# APASEV      34994  45100  77.592018
# ANXSEV      34311  45100  76.077605
# MINTTOTS    33956  45100  75.290466
# CRAFTDRE    33835  45100  75.022173
# MOCATOTS    33791  45100  74.924612
# IRRSEV      33786  45100  74.913525
# DIGBACCT    33644  45100  74.598670
# DIGBACLS    33644  45100  74.598670
# DIGFORSL    33610  45100  74.523282
# DIGFORCT    33610  45100  74.523282
# DEPDSEV     33007  45100  73.186253
# TRAILBLI    21772  45100  48.274945
# TRAILBRR    21768  45100  48.266075
# TRAILARR    19208  45100  42.589800
# TRAILALI    19070  45100  42.283814
# MEMTIME     16301  45100  36.144124
# CDRLANG     15794  45100  35.019956
# COMPORT     15794  45100  35.019956
# MEMUNITS    15773  45100  34.973392
# LOGIMEM     15694  45100  34.798226
# BOSTON      15636  45100  34.669623
# DIGIBLEN    15387  45100  34.117517
# DIGIB       15383  45100  34.108647
# DIGIFLEN    15287  45100  33.895787
# DIGIF       15274  45100  33.866962
# NACCMMSE    13820  45100  30.643016
# NACCAPOE    10487  45100  23.252772
# TRAILB       9326  45100  20.678492
# TAXES        6588  45100  14.607539
# TRAILA       5416  45100  12.008869
# GAMES        5410  45100  11.995565
# MEALPREP     5388  45100  11.946785
# BILLS        5041  45100  11.177384
# VEG          4047  45100   8.973392
# MEMPROB      3513  45100   7.789357
# STAYHOME     3459  45100   7.669623
# ANIMALS      3447  45100   7.643016
# BETTER       3440  45100   7.627494
# WONDRFUL     3429  45100   7.603104
# HAPPY        3427  45100   7.598670
# ENERGY       3419  45100   7.580931
# WRTHLESS     3411  45100   7.563193
# AFRAID       3408  45100   7.556541
# HOPELESS     3405  45100   7.549889
# HELPLESS     3399  45100   7.536585
# SPIRITS      3399  45100   7.536585
# DROPACT      3391  45100   7.518847
# EMPTY        3387  45100   7.509978
# SATIS        3384  45100   7.503326
# BORED        3382  45100   7.498891
# NACCGDS      3369  45100   7.470067
# NITE         2696  45100   5.977827
# APP          2470  45100   5.476718
# DEPD         2459  45100   5.452328
# MOT          2458  45100   5.450111
# DEL          2455  45100   5.443459
# ANX          2451  45100   5.434590
# HALL         2450  45100   5.432373
# APA          2448  45100   5.427938
# DISN         2443  45100   5.416851
# IRR          2441  45100   5.412417
# ELAT         2438  45100   5.405765
# AGIT         2432  45100   5.392461
# SHOPPING     2423  45100   5.372506
# STOVE        2198  45100   4.873614
# TRAVEL       1953  45100   4.330377
# EVENTS       1941  45100   4.303769
# PAYATTN      1715  45100   3.802661
# REMDATES     1651  45100   3.660754
# EDUC          360  45100   0.798226
# datetime        0  45100   0.000000
# SEX_BIN         0  45100   0.000000
# UDSD_LAB        0  45100   0.000000
# NACCID          0  45100   0.000000
# NACCADC         0  45100   0.000000
# CDRGLOB         0  45100   0.000000
# CDRSUM          0  45100   0.000000
# PERSCARE        0  45100   0.000000
# HOMEHOBB        0  45100   0.000000
# COMMUN          0  45100   0.000000
# JUDGMENT        0  45100   0.000000
# ORIENT          0  45100   0.000000
# MEMORY          0  45100   0.000000
# NACCALZP        0  45100   0.000000
# NACCUDSD        0  45100   0.000000
# SEX             0  45100   0.000000
# NACCVNUM        0  45100   0.000000
# NACCAGE         0  45100   0.000000
# ALZP_LAB        0  45100   0.000000

# %%
#want a proportion of missing values for each person excluding demographics/ visit number etc. 
uds['NUM_MIS_ROW'] = uds.isnull().sum(axis=1)/91
mri['NUM_MIS_ROW'] = mri.isnull().sum(axis=1)/167
csf['NUM_MIS_ROW'] = csf.isnull().sum(axis=1)/6

# %%
# Creating histogram
fig, axs = plt.subplots(figsize =(10, 7))
 
axs.hist(uds['NUM_MIS_ROW'])

plt.title('Proportion of Missing Values Per Person')
plt.xlabel('Proportion of Missing Values')
plt.ylabel('Frequency')
#plt.savefig('uds

# %%
# Creating histogram
fig, axs = plt.subplots(figsize =(10, 7))
 
axs.hist(uds['NUM_MIS_ROW'])

plt.title('UDS: Proportion of Missing Values Per Person')
plt.xlabel('Proportion of Missing Values')
plt.ylabel('Frequency')
plt.savefig('uds_missing_per_person.png')
# Show plot
plt.show()

# %%
# Creating histogram
fig, axs = plt.subplots(figsize =(10, 7))
 
axs.hist(mri['NUM_MIS_ROW'])

plt.title('MRI: Proportion of Missing Values Per Person')
plt.xlabel('Proportion of Missing Values')
plt.ylabel('Frequency')
plt.savefig('mri_missing_per_person.png')
# Show plot
plt.show()

# %%
# Creating histogram
fig, axs = plt.subplots(figsize =(10, 7))
 
axs.hist(csf['NUM_MIS_ROW'])

plt.title('CSF: Proportion of Missing Values Per Person')
plt.xlabel('Proportion of Missing Values')
plt.ylabel('Frequency')
plt.savefig('csf_missing_per_person.png')
# Show plot
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(
    pd.crosstab( uds.ALZP_3, uds.UDSD_3, 
            colnames=['Cognition'], 
            rownames=['Pathology'],
            values = uds['NUM_MIS_ROW'],
            aggfunc = 'mean',
            margins=False,
            margins_name="Total").round(2), 
    annot = True,
    cmap="Purples"
)
plt.title("UDS: Percentage Missing by Pathology and Cognition")
plt.savefig("missing_uds_by_UDSD_ALZP", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Boxplots
#
# want to look at histograms/ boxplots of distributions within the categories above, also why aren't we u
