# %% [markdown]
# # Latent Representation Learning
#
# This notebook implements the latent learning fusion method introduced in https://pubmed.ncbi.nlm.nih.gov/31021792/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
from importlib import reload
import seaborn as sns
import os, sys
import torch
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
target_encoder = LabelEncoder()
onehot_encoder = OneHotEncoder(sparse=False)

def load_data(impute_method = 'Mean-Mode', target = 'NACCAD3'):
    uds = pd.read_csv("../data/data_imputed/{}/uds.csv".format(impute_method))
    uds['datetime'] = pd.to_datetime(uds['datetime'])
    uds = uds.dropna(subset=[target, 'EDUC'])
    print("UDS Shape:  ", uds.shape)
    print("Target Distribution: {}\n".format(Counter(uds[target])))
    uds[target] = target_encoder.fit_transform(uds[target])
    onehot_encoder.fit(uds[target].values.reshape(-1, 1))
    mri = pd.read_csv("../data/data_imputed/{}/mri.csv".format(impute_method))
    mri['datetime'] = pd.to_datetime(mri['datetime'])
    
    csf = pd.read_csv("../data/data_imputed/{}/csf.csv".format(impute_method))
    return uds, mri, csf

uds_dict = pd.read_csv("../data/data_dictionary/uds_feature_dictionary_cleaned.csv")
mri_dict = pd.read_csv("../data/data_dictionary/mri_feature_dictionary_cleaned.csv") 

uds_drop_columns = ['NACCID', 'NACCADC', 'NACCVNUM', 'datetime', 'SEX', 'NACCAGE','EDUC', 
                    'NACCUDSD', 'NACCALZP', 'NACCAD3', 'NACCAD5']
mri_drop_columns = ['NACCID', 'NACCVNUM', 'datetime', 'datetime_UDS', 'timediff', 'within-a-year']
csf_drop_columns = ['NACCID', 'CSFABMD', 'CSFTTMD', 'CSFPTMD']

# %%
uds, mri, csf = load_data(impute_method = 'Mean-Mode', target = 'NACCAD3')
print(uds.shape, mri.shape, csf.shape)
# Out:
# UDS Shape:   (34025, 89)
# Target Distribution: Counter({'Healthy': 17673, 'Dementia-AD': 11882, 'MCI-AD': 4470})
#
# (34025, 89) (2873, 161) (2180, 7)

# %% [markdown]
# # Latent Representation Learning

# %%
common_pid = set(uds['NACCID']).intersection(mri['NACCID']).intersection(csf['NACCID'])
cpidTr, cpidTe = train_test_split(np.array(list(common_pid)), test_size = 0.3)

def train_test_split_modality(df, cpidTr, cpidTe):
    dfV = df[~df['NACCID'].isin(common_pid)]
    idx = dfV.index.to_frame()
    iTr, iTe = train_test_split(idx[0], test_size = 0.3)
    dfVTr, dfVTe = dfV.loc[iTr], dfV.loc[iTe]
    dfTr = pd.concat([df[df['NACCID'].isin(cpidTr)], dfVTr], axis=0).reset_index(drop=True)
    dfTe = pd.concat([df[df['NACCID'].isin(cpidTe)], dfVTe], axis=0).reset_index(drop=True)
    return dfTr, dfTe

mri, csf = mri[mri['NACCID'].isin(uds['NACCID'])], csf[csf['NACCID'].isin(uds['NACCID'])]
uds, mri, csf = uds.sort_values('NACCID'), mri.sort_values('NACCID'), csf.sort_values('NACCID')

udsTr, udsTe = train_test_split_modality(uds, cpidTr, cpidTe)
mriTr, mriTe = train_test_split_modality(mri, cpidTr, cpidTe)
csfTr, csfTe = train_test_split_modality(csf, cpidTr, cpidTe)

# %%
def prepare_X_Y(udsT, mriT, csfT, scalerU=None, scalerM=None, scalerC=None):
    XU, XM, XC = udsT.drop(uds_drop_columns, axis=1), mriT.drop(mri_drop_columns, axis=1), csfT.drop(csf_drop_columns, axis=1)
    if scalerU is None:
        scalerU, scalerM, scalerC = StandardScaler(), StandardScaler(), StandardScaler()
        XU, XM, XC = scalerU.fit_transform(XU).T, scalerM.fit_transform(XM).T, scalerC.fit_transform(XC).T
    else:
        XU, XM, XC = scalerU.transform(XU).T, scalerM.transform(XM).T, scalerC.transform(XC).T
    XU, XM, XC = torch.tensor(XU).float(), torch.tensor(XM).float(), torch.tensor(XC).float()

    YU, YM, YC = udsT['NACCAD3'], uds.merge(mriT, on='NACCID')['NACCAD3'], uds.merge(csfT, on='NACCID')['NACCAD3']
    YU, YM, YC = onehot_encoder.transform(YU.values.reshape(-1, 1)),onehot_encoder.transform(YM.values.reshape(-1, 1)),onehot_encoder.transform(YC.values.reshape(-1, 1))
    YU, YM, YC = torch.tensor(YU.T).float(), torch.tensor(YM.T).float(), torch.tensor(YC.T).float()
    return XU, XM, XC, YU, YM, YC, scalerU, scalerM, scalerC

# %%
def train_weights(W, X, H, E, Q, mu, verbose = False):
    for i in range(100):
        G = torch.diag((W**2).sum(1))
        W_new = torch.inverse(X.matmul(X.T) + (2*beta) / mu * G).matmul(X).matmul((H + E - Q / mu).T)
        if ((W_new - W)**2).sum() < 1e-6:
            break
        W = W_new
    if verbose and i == 100:
        print("Not converged")
    return W

def update_E(E, W, X, H, Q, mu):
    E_new = torch.zeros_like(E)
    temp = W.T.matmul(X) - H + Q / mu
    E_new = E_new + (temp > gamma / mu).int() * temp - gamma/mu
    E_new = E_new + (temp < -gamma / mu).int() * temp + gamma/mu
    return E_new

def calculate_accuracy(XU, XM, XC, YU, YM, YC, WU, WM, WC, P, nH):
    HU, HM, HC = WU.T.matmul(XU), WM.T.matmul(XM), WC.T.matmul(XC)
    H = (HU[:,:nH] + HM[:,:nH] + HC[:,:nH]) / 3
    YU_hat = P.matmul(torch.concat([H, HU[:,nH:]], axis=1)).argmax(axis=0)
    YM_hat = P.matmul(torch.concat([H, HM[:,nH:]], axis=1)).argmax(axis=0)
    YC_hat = P.matmul(torch.concat([H, HC[:,nH:]], axis=1)).argmax(axis=0)
    return "U-acc: {:.2f}%\tM-acc: {:.2f}%\tC-acc: {:.2f}%".format(
        (YU_hat == YU.argmax(0)).float().mean() * 100,
        (YM_hat == YM.argmax(0)).float().mean() * 100,
        (YC_hat == YC.argmax(0)).float().mean() * 100)
    
# maxiter, stop, rho, max_mu =1000, 1, 1.5, 1e6
def train_latent_features(maxiter=1000, stop = 1, rho = 1.5, mu=1e-2, max_mu = 1e6):
#     Train individual weights
    for i in range(maxiter):
        H = torch.randn(kH, nH)
        P = torch.randn(3, kH)
        WU, WM, WC = torch.randn(kU, kH), torch.randn(kM, kH), torch.randn(kC, kH)
        HU, EU, QU = torch.randn(kH, XU.shape[1]-nH), torch.randn(kH, XU.shape[1]), torch.ones(kH, XU.shape[1])
        HM, EM, QM = torch.randn(kH, XM.shape[1]-nH), torch.randn(kH, XM.shape[1]), torch.ones(kH, XM.shape[1])
        HC, EC, QC = torch.randn(kH, XC.shape[1]-nH), torch.randn(kH, XC.shape[1]), torch.ones(kH, XC.shape[1])

        WU = train_weights(WU, XU, torch.concat([H, HU], axis=1), EU, QU, mu)
        WM = train_weights(WM, XM, torch.concat([H, HM], axis=1), EM, QM, mu)
        WC = train_weights(WC, XC, torch.concat([H, HC], axis=1), EC, QC, mu)

        EU_new = update_E(EU, WU, XU, torch.concat([H, HU], axis=1), QU, mu)
        EM_new = update_E(EM, WM, XM, torch.concat([H, HM], axis=1), QM, mu)
        EC_new = update_E(EC, WC, XC, torch.concat([H, HC], axis=1), QC, mu)

        HU = torch.inverse((P.T.matmul(P)) + mu * torch.eye(kH)).matmul(
            P.T.matmul(YU[:,nH:]) + mu * (WU.T.matmul(XU[:,nH:]) - EU[:,nH:] + QU[:,nH:] / mu))
        HM = torch.inverse((P.T.matmul(P)) + mu * torch.eye(kH)).matmul(
            P.T.matmul(YM[:,nH:]) + mu * (WM.T.matmul(XM[:,nH:]) - EM[:,nH:] + QM[:,nH:] / mu))
        HC = torch.inverse((P.T.matmul(P)) + mu * torch.eye(kH)).matmul(
            P.T.matmul(YC[:,nH:]) + mu * (WC.T.matmul(XC[:,nH:]) - EC[:,nH:] + QC[:,nH:] / mu))

        # train global parameters
        H = torch.inverse(P.T.matmul(P) + mu * torch.eye(kH) * 3).matmul(P.T.matmul(YU[:,:nH]) + mu * (
        (WU.T.matmul(XU[:,:nH]) - EU[:,:nH] + QU[:,:nH] / mu) + 
        (WM.T.matmul(XM[:,:nH]) - EM[:,:nH] + QM[:,:nH] / mu) + 
        (WC.T.matmul(XC[:,:nH]) - EC[:,:nH] + QC[:,:nH] / mu)
        ))

        H_all = torch.concat([H, HU, HM, HC], axis=1)
        Y_all = torch.concat([YU[:,:nH], YU[:,nH:], YM[:,nH:], YC[:,nH:]],axis=1)
        P = Y_all.matmul(H_all.T).matmul(torch.inverse(H_all.matmul(H_all.T) + eta * torch.eye(kH)))

        QU = QU + mu * (WU.T.matmul(XU) - torch.concat([H, HU], axis=1) - EU)
        QM = QM + mu * (WM.T.matmul(XM) - torch.concat([H, HM], axis=1) - EM)
        QC = QC + mu * (WC.T.matmul(XC) - torch.concat([H, HC], axis=1) - EC)

        mu = min(rho * mu, max_mu)

        errU = torch.abs(WU.T.matmul(XU) - torch.concat([H, HU], axis=1) - EU).max()
        errM = torch.abs(WM.T.matmul(XM) - torch.concat([H, HM], axis=1) - EM).max()
        errC = torch.abs(WC.T.matmul(XC) - torch.concat([H, HC], axis=1) - EC).max()
        error = max(errU, errM, errC)
        if error < stop:
            break
        if i % 20 == 0:
            print("Iter {}:  error-{:.3f}\t{}".format(i, error, 
                                                    calculate_accuracy(XU, XM, XC, YU, YM, YC, WU, WM, WC, P, len(cpidTr))))
    if i == maxiter:
        print("Not Converged")
    return WU, WM, WC, P

# %%
XU, XM, XC, YU, YM, YC, scalerU, scalerM, scalerC = prepare_X_Y(udsTr, mriTr, csfTr)
kU, kM, kC = XU.shape[0], XM.shape[0], XC.shape[0]

nH, kH = len(cpidTr), 20
lamb, beta, gamma, eta = 0.1, 0.1, 0.1, 0.1

WU, WM, WC, P = train_latent_features(maxiter=5000, stop = 1, rho = 1.5, mu=1e-2, max_mu = 1e6)
# Out:
# Iter 0:  error-117.747	U-acc: 23.23%	M-acc: 19.69%	C-acc: 27.54%
# Iter 20:  error-3.490	U-acc: 57.17%	M-acc: 37.61%	C-acc: 39.89%
# Iter 40:  error-3.638	U-acc: 75.57%	M-acc: 40.80%	C-acc: 37.84%
# Iter 60:  error-2.931	U-acc: 71.25%	M-acc: 42.26%	C-acc: 42.25%
# Iter 80:  error-3.047	U-acc: 73.98%	M-acc: 38.65%	C-acc: 46.18%
# Iter 100:  error-3.479	U-acc: 70.40%	M-acc: 40.49%	C-acc: 29.66%
# Iter 120:  error-3.489	U-acc: 71.62%	M-acc: 39.27%	C-acc: 41.54%
# Iter 140:  error-3.264	U-acc: 72.99%	M-acc: 42.94%	C-acc: 43.67%
# Iter 160:  error-3.265	U-acc: 70.50%	M-acc: 42.26%	C-acc: 39.58%
# Iter 180:  error-3.247	U-acc: 68.08%	M-acc: 38.17%	C-acc: 40.52%
# Iter 200:  error-3.028	U-acc: 73.96%	M-acc: 39.33%	C-acc: 42.25%
# Iter 220:  error-3.467	U-acc: 64.07%	M-acc: 38.47%	C-acc: 40.91%
# Iter 240:  error-3.036	U-acc: 73.54%	M-acc: 41.04%	C-acc: 41.62%
# Iter 260:  error-3.049	U-acc: 74.76%	M-acc: 39.14%	C-acc: 42.41%
# Iter 280:  error-3.064	U-acc: 67.06%	M-acc: 38.59%	C-acc: 39.89%
# Iter 300:  error-3.145	U-acc: 70.78%	M-acc: 40.86%	C-acc: 44.53%
# Iter 320:  error-3.238	U-acc: 65.70%	M-acc: 37.98%	C-acc: 44.93%
# Iter 340:  error-3.231	U-acc: 66.55%	M-acc: 37.55%	C-acc: 43.19%
# Iter 360:  error-3.061	U-acc: 67.45%	M-acc: 35.84%	C-acc: 41.54%
# Iter 380:  error-3.395	U-acc: 67.92%	M-acc: 38.23%	C-acc: 41.31%
# Iter 400:  error-3.810	U-acc: 68.53%	M-acc: 39.57%	C-acc: 35.41%
# Iter 420:  error-3.373	U-acc: 70.37%	M-acc: 38.84%	C-acc: 41.54%
# Iter 440:  error-3.355	U-acc: 66.33%	M-acc: 36.57%	C-acc: 38.47%
# Iter 460:  error-3.387	U-acc: 68.09%	M-acc: 38.35%	C-acc: 34.30%
# Iter 480:  error-3.313	U-acc: 76.99%	M-acc: 40.18%	C-acc: 46.18%
# Iter 500:  error-3.123	U-acc: 66.26%	M-acc: 38.96%	C-acc: 34.93%
# Iter 520:  error-3.125	U-acc: 72.50%	M-acc: 38.72%	C-acc: 45.87%
# Iter 540:  error-3.018	U-acc: 70.32%	M-acc: 38.23%	C-acc: 42.88%
# Iter 560:  error-3.161	U-acc: 69.42%	M-acc: 40.31%	C-acc: 35.56%
# Iter 580:  error-3.167	U-acc: 67.58%	M-acc: 38.65%	C-acc: 32.49%
# Iter 600:  error-4.106	U-acc: 73.35%	M-acc: 37.80%	C-acc: 39.18%
# Iter 620:  error-3.236	U-acc: 76.34%	M-acc: 39.02%	C-acc: 47.60%
# Iter 640:  error-2.991	U-acc: 71.41%	M-acc: 40.37%	C-acc: 43.12%
# Iter 660:  error-3.566	U-acc: 66.75%	M-acc: 37.98%	C-acc: 41.46%
# Iter 680:  error-2.891	U-acc: 62.39%	M-acc: 36.57%	C-acc: 32.81%
# Iter 700:  error-3.565	U-acc: 70.40%	M-acc: 39.08%	C-acc: 38.79%
# Iter 720:  error-3.752	U-acc: 71.70%	M-acc: 39.63%	C-acc: 41.94%
# Iter 740:  error-3.433	U-acc: 71.25%	M-acc: 38.84%	C-acc: 40.20%
# Iter 760:  error-3.168	U-acc: 71.14%	M-acc: 41.04%	C-acc: 42.64%
# Iter 780:  error-3.213	U-acc: 69.95%	M-acc: 38.78%	C-acc: 40.91%
# Iter 800:  error-3.019	U-acc: 65.54%	M-acc: 37.98%	C-acc: 40.60%
# Iter 820:  error-3.307	U-acc: 73.59%	M-acc: 40.80%	C-acc: 40.76%
# Iter 840:  error-2.983	U-acc: 72.45%	M-acc: 42.39%	C-acc: 42.88%
# Iter 860:  error-3.500	U-acc: 61.98%	M-acc: 38.65%	C-acc: 34.23%
# Iter 880:  error-3.408	U-acc: 75.87%	M-acc: 38.84%	C-acc: 38.32%
# Iter 900:  error-3.375	U-acc: 74.92%	M-acc: 40.67%	C-acc: 44.69%
# Iter 920:  error-3.171	U-acc: 70.15%	M-acc: 40.06%	C-acc: 40.36%
# Iter 940:  error-3.763	U-acc: 68.40%	M-acc: 40.43%	C-acc: 40.52%
# Iter 960:  error-3.432	U-acc: 69.08%	M-acc: 39.39%	C-acc: 34.70%
# Iter 980:  error-3.121	U-acc: 71.12%	M-acc: 37.98%	C-acc: 43.51%
# Iter 1000:  error-3.424	U-acc: 61.06%	M-acc: 38.35%	C-acc: 38.95%
# Iter 1020:  error-3.211	U-acc: 73.15%	M-acc: 39.08%	C-acc: 39.26%
# Iter 1040:  error-3.582	U-acc: 70.95%	M-acc: 38.78%	C-acc: 44.06%
# Iter 1060:  error-3.367	U-acc: 70.84%	M-acc: 40.86%	C-acc: 48.47%
# Iter 1080:  error-3.043	U-acc: 73.70%	M-acc: 38.53%	C-acc: 41.78%
# Iter 1100:  error-3.221	U-acc: 72.44%	M-acc: 37.55%	C-acc: 38.95%
# Iter 1120:  error-3.267	U-acc: 72.26%	M-acc: 38.72%	C-acc: 44.69%
# Iter 1140:  error-3.302	U-acc: 73.98%	M-acc: 40.73%	C-acc: 45.40%
# Iter 1160:  error-3.228	U-acc: 70.37%	M-acc: 38.65%	C-acc: 34.23%
# Iter 1180:  error-3.432	U-acc: 69.19%	M-acc: 36.64%	C-acc: 42.25%
# Iter 1200:  error-4.184	U-acc: 74.39%	M-acc: 37.37%	C-acc: 38.16%
# Iter 1220:  error-3.189	U-acc: 68.64%	M-acc: 39.51%	C-acc: 34.70%
# Iter 1240:  error-4.010	U-acc: 73.48%	M-acc: 39.51%	C-acc: 39.02%
# Iter 1260:  error-3.064	U-acc: 72.35%	M-acc: 40.73%	C-acc: 42.64%
# Iter 1280:  error-3.455	U-acc: 64.43%	M-acc: 40.80%	C-acc: 42.49%
# Iter 1300:  error-3.136	U-acc: 71.82%	M-acc: 40.31%	C-acc: 46.58%
# Iter 1320:  error-3.205	U-acc: 69.25%	M-acc: 40.12%	C-acc: 42.96%
# Iter 1340:  error-3.529	U-acc: 72.85%	M-acc: 40.43%	C-acc: 39.02%
# Iter 1360:  error-3.323	U-acc: 71.91%	M-acc: 40.12%	C-acc: 40.13%
# Iter 1380:  error-3.203	U-acc: 69.02%	M-acc: 39.33%	C-acc: 34.70%
# Iter 1400:  error-3.518	U-acc: 73.69%	M-acc: 40.18%	C-acc: 33.36%
# Iter 1420:  error-3.231	U-acc: 70.91%	M-acc: 38.65%	C-acc: 39.02%
# Iter 1440:  error-3.565	U-acc: 72.07%	M-acc: 37.68%	C-acc: 45.40%
# Iter 1460:  error-3.544	U-acc: 73.48%	M-acc: 41.65%	C-acc: 44.77%
# Iter 1480:  error-2.952	U-acc: 73.11%	M-acc: 40.49%	C-acc: 43.98%
# Iter 1500:  error-3.863	U-acc: 66.68%	M-acc: 40.73%	C-acc: 36.98%
# Iter 1520:  error-3.301	U-acc: 72.04%	M-acc: 39.82%	C-acc: 36.11%
# Iter 1540:  error-3.146	U-acc: 68.10%	M-acc: 39.57%	C-acc: 38.08%
# Iter 1560:  error-2.968	U-acc: 71.77%	M-acc: 39.94%	C-acc: 46.81%
# Iter 1580:  error-3.458	U-acc: 66.71%	M-acc: 40.86%	C-acc: 50.20%
# Iter 1600:  error-3.502	U-acc: 75.30%	M-acc: 35.72%	C-acc: 43.75%
# Iter 1620:  error-3.888	U-acc: 67.81%	M-acc: 37.68%	C-acc: 43.43%
# Iter 1640:  error-3.321	U-acc: 75.46%	M-acc: 40.55%	C-acc: 39.97%
# Iter 1660:  error-3.235	U-acc: 70.64%	M-acc: 39.39%	C-acc: 39.42%
# Iter 1680:  error-2.964	U-acc: 63.27%	M-acc: 39.51%	C-acc: 45.24%
# Iter 1700:  error-3.452	U-acc: 69.95%	M-acc: 36.88%	C-acc: 43.82%
# Iter 1720:  error-2.862	U-acc: 73.52%	M-acc: 37.86%	C-acc: 40.13%
# Iter 1740:  error-3.117	U-acc: 65.10%	M-acc: 39.08%	C-acc: 42.96%
# Iter 1760:  error-3.666	U-acc: 68.37%	M-acc: 37.80%	C-acc: 37.45%
# Iter 1780:  error-2.972	U-acc: 73.44%	M-acc: 40.24%	C-acc: 40.36%
# Iter 1800:  error-3.274	U-acc: 76.20%	M-acc: 40.00%	C-acc: 26.12%
# Iter 1820:  error-3.548	U-acc: 70.72%	M-acc: 40.00%	C-acc: 45.00%
# Iter 1840:  error-3.401	U-acc: 61.56%	M-acc: 36.09%	C-acc: 36.82%
# Iter 1860:  error-3.224	U-acc: 69.37%	M-acc: 39.63%	C-acc: 46.42%
# Iter 1880:  error-3.341	U-acc: 69.10%	M-acc: 37.13%	C-acc: 43.82%
# Iter 1900:  error-3.503	U-acc: 73.63%	M-acc: 42.20%	C-acc: 39.42%
# Iter 1920:  error-3.073	U-acc: 68.04%	M-acc: 39.20%	C-acc: 38.32%
# Iter 1940:  error-3.266	U-acc: 71.51%	M-acc: 38.23%	C-acc: 41.38%
# Iter 1960:  error-3.190	U-acc: 70.99%	M-acc: 40.00%	C-acc: 42.33%
# Iter 1980:  error-3.478	U-acc: 70.41%	M-acc: 40.24%	C-acc: 39.26%
# Iter 2000:  error-3.884	U-acc: 73.72%	M-acc: 39.63%	C-acc: 39.89%
# Iter 2020:  error-3.108	U-acc: 71.03%	M-acc: 41.90%	C-acc: 42.56%
# Iter 2040:  error-3.086	U-acc: 72.36%	M-acc: 40.49%	C-acc: 45.71%
# Iter 2060:  error-2.982	U-acc: 70.70%	M-acc: 37.61%	C-acc: 35.96%
# Iter 2080:  error-3.145	U-acc: 64.91%	M-acc: 38.53%	C-acc: 42.80%
# Iter 2100:  error-3.050	U-acc: 69.82%	M-acc: 39.45%	C-acc: 42.64%
# Iter 2120:  error-3.189	U-acc: 71.57%	M-acc: 39.94%	C-acc: 39.42%
# Iter 2140:  error-3.435	U-acc: 70.03%	M-acc: 41.35%	C-acc: 39.02%
# Iter 2160:  error-3.311	U-acc: 72.06%	M-acc: 37.43%	C-acc: 43.67%
# Iter 2180:  error-3.136	U-acc: 70.07%	M-acc: 37.25%	C-acc: 42.33%
# Iter 2200:  error-3.922	U-acc: 67.68%	M-acc: 40.98%	C-acc: 47.76%
# Iter 2220:  error-3.162	U-acc: 69.59%	M-acc: 38.72%	C-acc: 43.12%
# Iter 2240:  error-3.111	U-acc: 73.24%	M-acc: 40.24%	C-acc: 43.59%
# Iter 2260:  error-3.059	U-acc: 73.86%	M-acc: 39.45%	C-acc: 44.93%
# Iter 2280:  error-3.215	U-acc: 72.33%	M-acc: 38.78%	C-acc: 40.76%
# Iter 2300:  error-3.798	U-acc: 75.44%	M-acc: 41.04%	C-acc: 44.85%
# Iter 2320:  error-3.061	U-acc: 71.38%	M-acc: 38.90%	C-acc: 42.56%
# Iter 2340:  error-3.236	U-acc: 73.63%	M-acc: 40.98%	C-acc: 43.04%
# Iter 2360:  error-3.287	U-acc: 68.33%	M-acc: 39.08%	C-acc: 32.57%
# Iter 2380:  error-3.034	U-acc: 71.69%	M-acc: 40.06%	C-acc: 45.24%
# Iter 2400:  error-4.073	U-acc: 71.19%	M-acc: 40.43%	C-acc: 41.54%
# Iter 2420:  error-3.054	U-acc: 71.70%	M-acc: 39.57%	C-acc: 41.70%
# Iter 2440:  error-3.262	U-acc: 74.58%	M-acc: 40.37%	C-acc: 48.23%
# Iter 2460:  error-2.963	U-acc: 59.91%	M-acc: 38.78%	C-acc: 44.06%
# Iter 2480:  error-3.114	U-acc: 73.63%	M-acc: 42.51%	C-acc: 35.01%
# Iter 2500:  error-3.149	U-acc: 72.30%	M-acc: 40.00%	C-acc: 38.87%
# Iter 2520:  error-3.485	U-acc: 71.42%	M-acc: 40.43%	C-acc: 48.78%
# Iter 2540:  error-3.072	U-acc: 73.08%	M-acc: 39.88%	C-acc: 38.79%
# Iter 2560:  error-3.233	U-acc: 66.48%	M-acc: 40.92%	C-acc: 39.65%
# Iter 2580:  error-3.249	U-acc: 75.02%	M-acc: 41.47%	C-acc: 42.41%
# Iter 2600:  error-3.293	U-acc: 69.10%	M-acc: 41.96%	C-acc: 43.90%
# Iter 2620:  error-3.259	U-acc: 74.96%	M-acc: 41.65%	C-acc: 47.21%
# Iter 2640:  error-3.111	U-acc: 73.22%	M-acc: 41.77%	C-acc: 40.52%
# Iter 2660:  error-3.034	U-acc: 74.26%	M-acc: 39.02%	C-acc: 42.80%
# Iter 2680:  error-3.015	U-acc: 74.58%	M-acc: 39.82%	C-acc: 44.93%
# Iter 2700:  error-3.314	U-acc: 73.34%	M-acc: 38.41%	C-acc: 45.16%
# Iter 2720:  error-3.252	U-acc: 70.62%	M-acc: 41.28%	C-acc: 48.70%
# Iter 2740:  error-3.073	U-acc: 70.93%	M-acc: 38.65%	C-acc: 44.93%
# Iter 2760:  error-2.910	U-acc: 69.58%	M-acc: 40.98%	C-acc: 45.55%
# Iter 2780:  error-3.249	U-acc: 57.57%	M-acc: 34.50%	C-acc: 36.90%
# Iter 2800:  error-3.395	U-acc: 71.62%	M-acc: 39.88%	C-acc: 35.96%
# Iter 2820:  error-3.280	U-acc: 72.96%	M-acc: 40.12%	C-acc: 48.86%
# Iter 2840:  error-3.263	U-acc: 71.54%	M-acc: 39.76%	C-acc: 39.97%
# Iter 2860:  error-3.144	U-acc: 70.41%	M-acc: 40.67%	C-acc: 35.33%
# Iter 2880:  error-3.065	U-acc: 72.95%	M-acc: 39.88%	C-acc: 43.12%
# Iter 2900:  error-2.973	U-acc: 77.43%	M-acc: 41.53%	C-acc: 38.32%
# Iter 2920:  error-3.284	U-acc: 76.09%	M-acc: 40.37%	C-acc: 35.72%
# Iter 2940:  error-2.941	U-acc: 62.61%	M-acc: 38.23%	C-acc: 35.17%
# Iter 2960:  error-3.249	U-acc: 72.67%	M-acc: 43.06%	C-acc: 41.31%
# Iter 2980:  error-3.630	U-acc: 71.75%	M-acc: 39.14%	C-acc: 48.62%
# Iter 3000:  error-3.179	U-acc: 69.86%	M-acc: 41.22%	C-acc: 41.54%
# Iter 3020:  error-3.207	U-acc: 68.31%	M-acc: 37.31%	C-acc: 46.11%
# Iter 3040:  error-3.307	U-acc: 75.76%	M-acc: 39.69%	C-acc: 28.17%
# Iter 3060:  error-3.130	U-acc: 74.58%	M-acc: 40.61%	C-acc: 41.23%
# Iter 3080:  error-2.921	U-acc: 72.20%	M-acc: 39.57%	C-acc: 39.97%
# Iter 3100:  error-3.901	U-acc: 71.63%	M-acc: 40.00%	C-acc: 28.80%
# Iter 3120:  error-3.743	U-acc: 68.89%	M-acc: 37.31%	C-acc: 38.00%
# Iter 3140:  error-3.128	U-acc: 74.82%	M-acc: 40.98%	C-acc: 40.91%
# Iter 3160:  error-3.269	U-acc: 70.99%	M-acc: 38.78%	C-acc: 39.58%
# Iter 3180:  error-3.212	U-acc: 72.86%	M-acc: 38.29%	C-acc: 40.44%
# Iter 3200:  error-3.472	U-acc: 69.85%	M-acc: 38.72%	C-acc: 42.80%
# Iter 3220:  error-2.951	U-acc: 64.75%	M-acc: 35.17%	C-acc: 33.04%
# Iter 3240:  error-3.285	U-acc: 72.19%	M-acc: 40.98%	C-acc: 45.55%
# Iter 3260:  error-3.368	U-acc: 68.08%	M-acc: 40.31%	C-acc: 41.31%
# Iter 3280:  error-2.963	U-acc: 68.92%	M-acc: 39.14%	C-acc: 44.30%
# Iter 3300:  error-3.195	U-acc: 73.19%	M-acc: 42.26%	C-acc: 33.28%
# Iter 3320:  error-2.994	U-acc: 71.52%	M-acc: 39.82%	C-acc: 38.63%
# Iter 3340:  error-2.973	U-acc: 77.69%	M-acc: 40.06%	C-acc: 44.93%
# Iter 3360:  error-3.230	U-acc: 72.98%	M-acc: 38.72%	C-acc: 45.24%
# Iter 3380:  error-3.365	U-acc: 75.54%	M-acc: 41.16%	C-acc: 42.56%
# Iter 3400:  error-3.253	U-acc: 61.68%	M-acc: 36.94%	C-acc: 26.75%
# Iter 3420:  error-3.663	U-acc: 66.32%	M-acc: 37.86%	C-acc: 42.72%
# Iter 3440:  error-3.572	U-acc: 76.90%	M-acc: 40.49%	C-acc: 47.76%
# Iter 3460:  error-3.078	U-acc: 67.81%	M-acc: 37.25%	C-acc: 42.56%
# Iter 3480:  error-2.923	U-acc: 66.18%	M-acc: 39.08%	C-acc: 42.88%
# Iter 3500:  error-2.883	U-acc: 75.03%	M-acc: 40.73%	C-acc: 45.16%
# Iter 3520:  error-3.454	U-acc: 71.83%	M-acc: 38.96%	C-acc: 40.91%
# Iter 3540:  error-3.217	U-acc: 67.45%	M-acc: 39.57%	C-acc: 39.10%
# Iter 3560:  error-3.358	U-acc: 67.51%	M-acc: 39.69%	C-acc: 38.16%
# Iter 3580:  error-3.021	U-acc: 76.26%	M-acc: 36.39%	C-acc: 42.33%
# Iter 3600:  error-3.100	U-acc: 69.19%	M-acc: 39.02%	C-acc: 41.15%
# Iter 3620:  error-3.141	U-acc: 70.81%	M-acc: 39.45%	C-acc: 46.50%
# Iter 3640:  error-3.664	U-acc: 71.17%	M-acc: 37.86%	C-acc: 41.62%
# Iter 3660:  error-3.061	U-acc: 68.44%	M-acc: 41.04%	C-acc: 44.06%
# Iter 3680:  error-3.091	U-acc: 68.99%	M-acc: 39.20%	C-acc: 43.90%
# Iter 3700:  error-3.581	U-acc: 70.05%	M-acc: 39.33%	C-acc: 43.04%
# Iter 3720:  error-3.335	U-acc: 76.22%	M-acc: 36.94%	C-acc: 46.34%
# Iter 3740:  error-3.368	U-acc: 64.90%	M-acc: 40.61%	C-acc: 36.51%
# Iter 3760:  error-3.268	U-acc: 74.44%	M-acc: 41.41%	C-acc: 43.98%
# Iter 3780:  error-3.195	U-acc: 70.75%	M-acc: 39.08%	C-acc: 43.19%
# Iter 3800:  error-3.289	U-acc: 72.98%	M-acc: 40.67%	C-acc: 45.87%
# Iter 3820:  error-3.084	U-acc: 73.44%	M-acc: 40.31%	C-acc: 46.66%
# Iter 3840:  error-3.075	U-acc: 72.93%	M-acc: 40.98%	C-acc: 43.51%
# Iter 3860:  error-3.297	U-acc: 71.55%	M-acc: 40.73%	C-acc: 47.99%
# Iter 3880:  error-3.284	U-acc: 68.99%	M-acc: 40.49%	C-acc: 34.93%
# Iter 3900:  error-3.216	U-acc: 67.20%	M-acc: 40.24%	C-acc: 41.54%
# Iter 3920:  error-3.361	U-acc: 68.50%	M-acc: 38.53%	C-acc: 36.74%
# Iter 3940:  error-3.161	U-acc: 75.43%	M-acc: 38.84%	C-acc: 42.56%
# Iter 3960:  error-3.069	U-acc: 71.63%	M-acc: 40.55%	C-acc: 36.98%
# Iter 3980:  error-3.255	U-acc: 62.13%	M-acc: 32.35%	C-acc: 30.13%
# Iter 4000:  error-3.337	U-acc: 68.10%	M-acc: 35.35%	C-acc: 38.55%
# Iter 4020:  error-2.970	U-acc: 66.36%	M-acc: 39.20%	C-acc: 35.80%
# Iter 4040:  error-3.054	U-acc: 74.66%	M-acc: 41.41%	C-acc: 45.32%
# Iter 4060:  error-3.247	U-acc: 71.26%	M-acc: 40.24%	C-acc: 42.09%
# Iter 4080:  error-3.081	U-acc: 67.43%	M-acc: 39.88%	C-acc: 40.13%
# Iter 4100:  error-4.000	U-acc: 66.85%	M-acc: 37.61%	C-acc: 30.45%
# Iter 4120:  error-3.088	U-acc: 71.42%	M-acc: 41.41%	C-acc: 47.29%
# Iter 4140:  error-3.358	U-acc: 65.34%	M-acc: 35.23%	C-acc: 32.49%
# Iter 4160:  error-3.223	U-acc: 75.08%	M-acc: 39.82%	C-acc: 45.79%
# Iter 4180:  error-3.586	U-acc: 71.52%	M-acc: 39.69%	C-acc: 44.85%
# Iter 4200:  error-3.094	U-acc: 73.99%	M-acc: 41.10%	C-acc: 38.47%
# Iter 4220:  error-2.922	U-acc: 72.77%	M-acc: 39.76%	C-acc: 40.44%
# Iter 4240:  error-3.435	U-acc: 72.38%	M-acc: 39.88%	C-acc: 41.94%
# Iter 4260:  error-3.504	U-acc: 69.51%	M-acc: 40.43%	C-acc: 42.72%
# Iter 4280:  error-3.340	U-acc: 69.50%	M-acc: 38.35%	C-acc: 36.27%
# Iter 4300:  error-3.523	U-acc: 67.66%	M-acc: 36.94%	C-acc: 45.00%
# Iter 4320:  error-3.215	U-acc: 67.50%	M-acc: 40.86%	C-acc: 42.17%
# Iter 4340:  error-3.336	U-acc: 70.07%	M-acc: 40.00%	C-acc: 49.41%
# Iter 4360:  error-3.637	U-acc: 72.90%	M-acc: 40.55%	C-acc: 38.63%
# Iter 4380:  error-3.223	U-acc: 70.20%	M-acc: 37.80%	C-acc: 46.34%
# Iter 4400:  error-3.368	U-acc: 74.73%	M-acc: 42.02%	C-acc: 46.81%
# Iter 4420:  error-3.093	U-acc: 72.34%	M-acc: 38.35%	C-acc: 35.48%
# Iter 4440:  error-3.247	U-acc: 71.84%	M-acc: 38.96%	C-acc: 41.15%
# Iter 4460:  error-3.253	U-acc: 72.60%	M-acc: 36.21%	C-acc: 38.63%
# Iter 4480:  error-3.503	U-acc: 71.28%	M-acc: 41.28%	C-acc: 46.42%
# Iter 4500:  error-3.339	U-acc: 74.89%	M-acc: 38.96%	C-acc: 41.54%
# Iter 4520:  error-3.209	U-acc: 70.98%	M-acc: 38.72%	C-acc: 46.42%
# Iter 4540:  error-3.397	U-acc: 70.25%	M-acc: 39.57%	C-acc: 38.00%
# Iter 4560:  error-4.125	U-acc: 68.09%	M-acc: 39.57%	C-acc: 40.52%
# Iter 4580:  error-3.130	U-acc: 71.99%	M-acc: 38.90%	C-acc: 47.60%
# Iter 4600:  error-3.504	U-acc: 72.17%	M-acc: 40.80%	C-acc: 31.39%
# Iter 4620:  error-3.810	U-acc: 74.92%	M-acc: 40.18%	C-acc: 35.64%
# Iter 4640:  error-3.491	U-acc: 74.47%	M-acc: 40.06%	C-acc: 34.54%
# Iter 4660:  error-2.966	U-acc: 69.10%	M-acc: 37.98%	C-acc: 42.64%
# Iter 4680:  error-3.012	U-acc: 72.01%	M-acc: 39.33%	C-acc: 40.76%
# Iter 4700:  error-3.181	U-acc: 69.00%	M-acc: 37.61%	C-acc: 38.08%
# Iter 4720:  error-3.157	U-acc: 66.75%	M-acc: 39.57%	C-acc: 36.74%
# Iter 4740:  error-3.285	U-acc: 67.88%	M-acc: 39.76%	C-acc: 45.24%
# Iter 4760:  error-3.145	U-acc: 70.93%	M-acc: 42.39%	C-acc: 48.70%
# Iter 4780:  error-3.196	U-acc: 73.55%	M-acc: 38.17%	C-acc: 41.38%
# Iter 4800:  error-3.425	U-acc: 67.04%	M-acc: 38.72%	C-acc: 40.83%
# Iter 4820:  error-3.231	U-acc: 71.52%	M-acc: 38.84%	C-acc: 43.59%
# Iter 4840:  error-3.175	U-acc: 73.69%	M-acc: 40.80%	C-acc: 40.60%
# Iter 4860:  error-3.099	U-acc: 70.53%	M-acc: 37.00%	C-acc: 38.87%
# Iter 4880:  error-3.193	U-acc: 70.47%	M-acc: 40.86%	C-acc: 47.76%
# Iter 4900:  error-3.287	U-acc: 71.99%	M-acc: 40.67%	C-acc: 36.90%
# Iter 4920:  error-3.080	U-acc: 72.25%	M-acc: 39.33%	C-acc: 26.91%
# Iter 4940:  error-3.395	U-acc: 69.21%	M-acc: 37.68%	C-acc: 42.80%
# Iter 4960:  error-3.219	U-acc: 69.44%	M-acc: 37.92%	C-acc: 40.13%
# Iter 4980:  error-3.134	U-acc: 71.40%	M-acc: 40.86%	C-acc: 41.86%

# %%
XUTe, XMTe, XCTe, YUTe, YMTe, YCTe, scalerU, scalerM, scalerC = prepare_X_Y(udsTe, mriTe, csfTe, scalerU, scalerM, scalerC)

# %%
print(calculate_accuracy(XUTe, XMTe, XCTe, YUTe, YMTe, YCTe, WU, WM, WC, P, len(cpidTr)))
# Out:
# U-acc: 73.23%	M-acc: 36.84%	C-acc: 39.31%
